# %%
"""
Authors: Ritvik Kapila, Gauri Gupta
"""
import pandas as pd 
import numpy as np
import xml.etree.ElementTree as etree
import sys

# %%
# Counting the number of children of a given node

def total_entries(node):
    count = 0
    for i in range(sys.maxsize):
        try:
            node[i]
            count += 1
        except:
            return count

# %%
# Removing unsupported characters from the sheet names in excel

def column_name(s):
    s1 = ""
    for i in range(len(s)):
        if not(s[i] == ']' or s[i] == '[' or s[i] == ':' or s[i] == '*' or s[i] == '?' or s[i] == '/'):
            s1 = s1 + s[i]
        else:
            s1 = s1 + "_"
    return s1

# %%
# Renaming excel sheet if the name exceeds given characters 

def excel_name(d):
    count = 1
    d1 = {}
    for i in d:
        if len(i)>29:
            i1 = i[:29] + str(count)
            count = count + 1
            d1[i1] = d[i]
        else :
            d1[i] = d[i]
    return d1

# %%
# This function combines the data in child nodes of the list attributes and outputs a list

def entry_list(node):
    l1 = []
    for i in range(total_entries(node)):
        if node[i].text == "\n          ":
            ltemp = []
            for j in range(total_entries(node[i])):
                ltemp = ltemp + [node[i][j].attrib['name'] + ": " + node[i][j].text]
            l1.append(ltemp)    
        else :
            l1.append(node[i].text)
    return l1
     
#     for i in range(total_entries(node)):
#                 l = l + [(node[i].text)]
#                 return l  
#     else:
#         return entry_list(node[0])

# %%
# Converts the entire xml document to a dictionary containing different dataframes for each sheet attribute with keys as sheet names

def data_xml(root, sheet_attrib):
    
#     Creating the dictionary format
    keyList = []
    n = total_entries(root[0])
    for i in range(n):
        if i>0:
#             print(root[0][i].tag, "\n", root[0][i].attrib, "\n", root[0][i].text)
            keyList = keyList + [column_name(root[0][i].attrib[sheet_attrib])]
    dictionary = {}
    for i in keyList: 
        dictionary[i] = 'None'
#     print(dictionary)    
#     Adding data to the dictionary
    for i in range(n):
        if i>0:
            currNode = root[0][i]
            print(str(i)+str(currNode.attrib[sheet_attrib]))
#             print(currNode.attrib[sheet_attrib][0])
            try:    
                if dictionary[column_name(currNode.attrib[sheet_attrib])] == 'None':
#                     print('empty' + currNode.attrib[sheet_attrib])
                    columns = []
                    values = []
                    for key in currNode.attrib:
                        if key == sheet_attrib:
                            continue
                        else:
                            columns = columns + [key]
                            values = values + [currNode.attrib[key]]
                    for j in range(total_entries(root[0][i])):
#                         print('yes')
                        if(currNode[j].tag == 'p' or currNode[j].tag == '{raml21.xsd}p'):
                            columns = columns + [currNode[j].attrib['name']]
                            values = values + [currNode[j].text]
                        elif (currNode[j].tag == 'list' or currNode[j].tag == '{raml21.xsd}list'):
                            columns = columns + [currNode[j].attrib['name']]
                            values = values + [entry_list(currNode[j])]

                    df = pd.DataFrame([values], columns = columns)
                    dictionary[column_name(currNode.attrib[sheet_attrib])] = df
#                     print(total_entries(currNode)) 
#                     print((dictionary))
            except:
#                 print('filled' + root[0][i].attrib[sheet_attrib])
                columns = []
                values = []
                for key in currNode.attrib:
                    if key == sheet_attrib:
                        continue
                    else:
                        columns = columns + [key]
                        values = values + [currNode.attrib[key]]                    
                for j in range(total_entries(root[0][i])):
                    if(currNode[j].tag == 'p' or currNode[j].tag == '{raml21.xsd}p'):
                        columns = columns + [currNode[j].attrib['name']]
                        values = values + [currNode[j].text]
                    elif (currNode[j].tag == 'list' or currNode[j].tag == '{raml21.xsd}list'):
                        columns = columns + [currNode[j].attrib['name']]
                        values = values + [entry_list(currNode[j])]
                                               
                df = pd.DataFrame([values], columns = columns)
                dictionary[column_name(currNode.attrib[sheet_attrib])] = dictionary[column_name(currNode.attrib[sheet_attrib])].append(df)
#                 print(total_entries(currNode)) 
#                 print((dictionary))
    return excel_name(dictionary)

# %%
# Converts an input xml file to output xlsx file given the sheet attribute for creating sheets in xlsx

def xml_to_xlsx(input_file, sheet_attrib, output_file):
    # Reading the xml as a tree object
    
    tree = etree.parse(input_file)
    root = tree.getroot()
    
    dfs = data_xml(root, sheet_attrib)
    
    # Opens the output file for writing

    writer = pd.ExcelWriter(output_file + '.xlsx', engine = 'xlsxwriter')
    
    # Writing the data from the dictionary onto the excel sheet

    for sheet_name in dfs.keys():
        dfs[sheet_name].to_excel(writer, sheet_name = sheet_name, index = False)

    writer.save()

# %%
xml_to_xlsx('SRAT Hardware dump_1.xml', 'class', 'SRAT')
# Out:
# 1RNC
# 2RNC
# 3RNC
# 4RNC
# 5RNC
# 6RNC
# 7RNC
# 8RNC
# 9RNC
# 10RNC
# 11RNC
# 12RNC
# 13RNC
# 14RNC
# 15RNC
# 16RNC
# 17RNC
# 18WBTS
# 19WBTS
# 20WBTS
# 21WBTS
# 22WBTS
# 23WBTS
# 24WBTS
# 25WBTS
# 26WBTS
# 27WBTS
# 28WBTS
# 29WBTS
# 30WBTS
# 31WBTS
# 32WBTS
# 33WBTS
# 34WBTS
# 35WBTS
# 36WBTS
# 37WBTS
# 38WBTS
# 39WBTS
# 40WBTS
# 41WBTS
# 42WBTS
# 43WBTS
# 44WBTS
# 45WBTS
# 46WBTS
# 47WBTS
# 48WBTS
# 49WBTS
# 50WBTS
# 51WBTS
# 52WBTS
# 53WBTS
# 54WBTS
# 55WBTS
# 56WBTS
# 57WBTS
# 58WBTS
# 59WBTS
# 60WBTS
# 61WBTS
# 62WBTS
# 63WBTS
# 64WBTS
# 65WBTS
# 66WBTS
# 67WBTS
# 68WBTS
# 69WBTS
# 70WBTS
# 71WBTS
# 72WBTS
# 73WBTS
# 74WBTS
# 75WBTS
# 76WBTS
# 77WBTS
# 78WBTS
# 79WBTS
# 80WBTS
# 81WBTS
# 82WBTS
# 83WBTS
# 84WBTS
# 85WBTS
# 86WBTS
# 87WBTS
# 88WBTS
# 89WBTS
# 90WBTS
# 91WBTS
# 92WBTS
# 93WBTS
# 94WBTS
# 95WBTS
# 96WBTS
# 97WBTS
# 98WBTS
# 99WBTS
# 100WBTS
# 101WBTS
# 102WBTS
# 103WBTS
# 104WBTS
# 105WBTS
# 106WBTS
# 107WBTS
# 108WBTS
# 109WBTS
# 110WBTS
# 111WCEL
# 112WCEL
# 113WCEL
# 114WCEL
# 115WCEL
# 116WCEL
# 117WCEL
# 118WCEL
# 119WCEL
# 120WCEL
# 121WCEL
# 122WCEL
# 123WCEL
# 124WCEL
# 125WCEL
# 126WCEL
# 127WCEL
# 128WCEL
# 129WCEL
# 130WCEL
# 131WCEL
# 132WCEL
# 133WCEL
# 134WCEL
# 135WCEL
# 136WCEL
# 137WCEL
# 138WCEL
# 139WCEL
# 140WCEL
# 141WCEL
# 142WCEL
# 143WCEL
# 144WCEL
# 145WCEL
# 146WCEL
# 147WCEL
# 148WCEL
# 149WCEL
# 150WCEL
# 151WCEL
# 152WCEL
# 153WCEL
# 154WCEL
# 155WCEL
# 156WCEL
# 157WCEL
# 158WCEL
# 159WCEL
# 160WCEL
# 161WCEL
# 162WCEL
# 163WCEL
# 164WCEL
# 165MRBTS
# 166HW
# 167WCEL
# 168WCEL
# 169WCEL
# 170WCEL
# 171WCEL
# 172WCEL
# 173WCEL
# 174WCEL
# 175WCEL
# 176MRBTS
# 177HW
# 178WCEL
# 179WCEL
# 180WCEL
# 181WCEL
# 182WCEL
# 183WCEL
# 184WCEL
# 185WCEL
# 186WCEL
# 187MRBTS
# 188HW
# 189WCEL
# 190WCEL
# 191WCEL
# 192MRBTS
# 193HW
# 194WCEL
# 195WCEL
# 196WCEL
# 197WCEL
# 198WCEL
# 199WCEL
# 200WCEL
# 201WCEL
# 202WCEL
# 203WCEL
# 204WCEL
# 205WCEL
# 206WCEL
# 207WCEL
# 208WCEL
# 209WCEL
# 210WCEL
# 211WCEL
# 212WCEL
# 213WCEL
# 214WCEL
# 215MRBTS
# 216HW
# 217WCEL
# 218WCEL
# 219WCEL
# 220WCEL
# 221WCEL
# 222WCEL
# 223WCEL
# 224WCEL
# 225WCEL
# 226WCEL
# 227WCEL
# 228WCEL
# 229MRBTS
# 230HW
# 231WCEL
# 232WCEL
# 233WCEL
# 234WCEL
# 235WCEL
# 236WCEL
# 237MRBTS
# 238HW
# 239WCEL
# 240WCEL
# 241WCEL
# 242WCEL
# 243WCEL
# 244WCEL
# 245WCEL
# 246WCEL
# 247WCEL
# 248WCEL
# 249WCEL
# 250WCEL
# 251MRBTS
# 252HW
# 253WCEL
# 254WCEL
# 255WCEL
# 256WCEL
# 257WCEL
# 258WCEL
# 259WCEL
# 260WCEL
# 261WCEL
# 262MRBTS
# 263HW
# 264WCEL
# 265WCEL
# 266WCEL
# 267WCEL
# 268WCEL
# 269WCEL
# 270WCEL
# 271WCEL
# 272WCEL
# 273MRBTS
# 274HW
# 275WCEL
# 276WCEL
# 277WCEL
# 278WCEL
# 279WCEL
# 280WCEL
# 281WCEL
# 282WCEL
# 283WCEL
# 284MRBTS
# 285HW
# 286WCEL
# 287WCEL
# 288WCEL
# 289WCEL
# 290WCEL
# 291WCEL
# 292WCEL
# 293WCEL
# 294WCEL
# 295MRBTS
# 296HW
# 297WCEL
# 298WCEL
# 299WCEL
# 300WCEL
# 301WCEL
# 302WCEL
# 303WCEL
# 304WCEL
# 305WCEL
# 306MRBTS
# 307HW
# 308WCEL
# 309WCEL
# 310WCEL
# 311WCEL
# 312WCEL
# 313WCEL
# 314WCEL
# 315WCEL
# 316WCEL
# 317MRBTS
# 318HW
# 319WCEL
# 320WCEL
# 321WCEL
# 322MRBTS
# 323HW
# 324WCEL
# 325WCEL
# 326WCEL
# 327WCEL
# 328WCEL
# 329WCEL
# 330WCEL
# 331WCEL
# 332WCEL
# 333MRBTS
# 334HW
# 335WCEL
# 336WCEL
# 337WCEL
# 338WCEL
# 339WCEL
# 340WCEL
# 341WCEL
# 342WCEL
# 343WCEL
# 344MRBTS
# 345HW
# 346WCEL
# 347WCEL
# 348WCEL
# 349WCEL
# 350WCEL
# 351WCEL
# 352WCEL
# 353WCEL
# 354WCEL
# 355MRBTS
# 356HW
# 357WCEL
# 358WCEL
# 359WCEL
# 360WCEL
# 361WCEL
# 362WCEL
# 363WCEL
# 364WCEL
# 365WCEL
# 366MRBTS
# 367HW
# 368WCEL
# 369WCEL
# 370WCEL
# 371WCEL
# 372WCEL
# 373WCEL
# 374WCEL
# 375WCEL
# 376WCEL
# 377MRBTS
# 378HW
# 379WCEL
# 380WCEL
# 381WCEL
# 382MRBTS
# 383HW
# 384WCEL
# 385WCEL
# 386WCEL
# 387MRBTS
# 388HW
# 389WCEL
# 390WCEL
# 391WCEL
# 392MRBTS
# 393HW
# 394WCEL
# 395WCEL
# 396WCEL
# 397WCEL
# 398WCEL
# 399WCEL
# 400WCEL
# 401WCEL
# 402WCEL
# 403MRBTS
# 404HW
# 405WCEL
# 406WCEL
# 407WCEL
# 408WCEL
# 409WCEL
# 410WCEL
# 411WCEL
# 412WCEL
# 413WCEL
# 414MRBTS
# 415HW
# 416WCEL
# 417WCEL
# 418WCEL
# 419WCEL
# 420WCEL
# 421WCEL
# 422WCEL
# 423WCEL
# 424WCEL
# 425MRBTS
# 426HW
# 427WCEL
# 428WCEL
# 429WCEL
# 430WCEL
# 431WCEL
# 432WCEL
# 433WCEL
# 434WCEL
# 435WCEL
# 436MRBTS
# 437HW
# 438WCEL
# 439WCEL
# 440WCEL
# 441WCEL
# 442WCEL
# 443WCEL
# 444WCEL
# 445WCEL
# 446WCEL
# 447MRBTS
# 448HW
# 449WCEL
# 450WCEL
# 451WCEL
# 452WCEL
# 453WCEL
# 454WCEL
# 455WCEL
# 456WCEL
# 457WCEL
# 458MRBTS
# 459HW
# 460WCEL
# 461WCEL
# 462WCEL
# 463WCEL
# 464WCEL
# 465WCEL
# 466WCEL
# 467WCEL
# 468WCEL
# 469MRBTS
# 470HW
# 471WCEL
# 472WCEL
# 473WCEL
# 474WCEL
# 475WCEL
# 476WCEL
# 477WCEL
# 478WCEL
# 479WCEL
# 480MRBTS
# 481HW
# 482WCEL
# 483WCEL
# 484WCEL
# 485WCEL
# 486WCEL
# 487WCEL
# 488WCEL
# 489WCEL
# 490WCEL
# 491MRBTS
# 492HW
# 493WCEL
# 494WCEL
# 495WCEL
# 496WCEL
# 497WCEL
# 498WCEL
# 499WCEL
# 500WCEL
# 501WCEL
# 502MRBTS
# 503HW
# 504WCEL
# 505WCEL
# 506WCEL
# 507MRBTS
# 508HW
# 509WCEL
# 510WCEL
# 511WCEL
# 512WCEL
# 513WCEL
# 514WCEL
# 515WCEL
# 516WCEL
# 517WCEL
# 518MRBTS
# 519HW
# 520WCEL
# 521WCEL
# 522WCEL
# 523WCEL
# 524WCEL
# 525WCEL
# 526WCEL
# 527WCEL
# 528WCEL
# 529MRBTS
# 530HW
# 531WCEL
# 532WCEL
# 533WCEL
# 534WCEL
# 535WCEL
# 536WCEL
# 537WCEL
# 538WCEL
# 539WCEL
# 540MRBTS
# 541HW
# 542WCEL
# 543WCEL
# 544WCEL
# 545MRBTS
# 546HW
# 547WCEL
# 548WCEL
# 549WCEL
# 550WCEL
# 551WCEL
# 552WCEL
# 553WCEL
# 554WCEL
# 555WCEL
# 556MRBTS
# 557HW
# 558WCEL
# 559WCEL
# 560WCEL
# 561WCEL
# 562WCEL
# 563WCEL
# 564WCEL
# 565WCEL
# 566WCEL
# 567MRBTS
# 568HW
# 569WCEL
# 570WCEL
# 571WCEL
# 572WCEL
# 573WCEL
# 574WCEL
# 575WCEL
# 576WCEL
# 577WCEL
# 578MRBTS
# 579HW
# 580WCEL
# 581WCEL
# 582WCEL
# 583WCEL
# 584WCEL
# 585WCEL
# 586WCEL
# 587WCEL
# 588WCEL
# 589MRBTS
# 590HW
# 591WCEL
# 592WCEL
# 593WCEL
# 594WCEL
# 595WCEL
# 596WCEL
# 597WCEL
# 598WCEL
# 599WCEL
# 600MRBTS
# 601HW
# 602WCEL
# 603WCEL
# 604WCEL
# 605MRBTS
# 606HW
# 607WCEL
# 608WCEL
# 609WCEL
# 610WCEL
# 611WCEL
# 612WCEL
# 613WCEL
# 614WCEL
# 615WCEL
# 616MRBTS
# 617HW
# 618WCEL
# 619WCEL
# 620WCEL
# 621MRBTS
# 622HW
# 623WCEL
# 624WCEL
# 625WCEL
# 626WCEL
# 627WCEL
# 628WCEL
# 629WCEL
# 630WCEL
# 631WCEL
# 632MRBTS
# 633HW
# 634WCEL
# 635WCEL
# 636WCEL
# 637WCEL
# 638WCEL
# 639WCEL
# 640WCEL
# 641WCEL
# 642WCEL
# 643MRBTS
# 644HW
# 645WCEL
# 646WCEL
# 647WCEL
# 648WCEL
# 649WCEL
# 650WCEL
# 651WCEL
# 652WCEL
# 653WCEL
# 654MRBTS
# 655HW
# 656WCEL
# 657WCEL
# 658WCEL
# 659WCEL
# 660WCEL
# 661WCEL
# 662WCEL
# 663WCEL
# 664WCEL
# 665MRBTS
# 666HW
# 667WCEL
# 668WCEL
# 669WCEL
# 670WCEL
# 671WCEL
# 672WCEL
# 673WCEL
# 674WCEL
# 675WCEL
# 676MRBTS
# 677HW
# 678WCEL
# 679WCEL
# 680WCEL
# 681WCEL
# 682WCEL
# 683WCEL
# 684MRBTS
# 685HW
# 686WCEL
# 687WCEL
# 688WCEL
# 689MRBTS
# 690HW
# 691WCEL
# 692WCEL
# 693WCEL
# 694WCEL
# 695WCEL
# 696WCEL
# 697WCEL
# 698WCEL
# 699WCEL
# 700MRBTS
# 701HW
# 702WCEL
# 703WCEL
# 704WCEL
# 705WCEL
# 706WCEL
# 707WCEL
# 708MRBTS
# 709HW
# 710WCEL
# 711WCEL
# 712WCEL
# 713WCEL
# 714WCEL
# 715WCEL
# 716WCEL
# 717WCEL
# 718WCEL
# 719MRBTS
# 720HW
# 721WCEL
# 722WCEL
# 723WCEL
# 724WCEL
# 725WCEL
# 726WCEL
# 727WCEL
# 728WCEL
# 729WCEL
# 730MRBTS
# 731HW
# 732WCEL
# 733WCEL
# 734WCEL
# 735WCEL
# 736WCEL
# 737WCEL
# 738WCEL
# 739WCEL
# 740WCEL
# 741MRBTS
# 742HW
# 743WCEL
# 744WCEL
# 745WCEL
# 746WCEL
# 747WCEL
# 748WCEL
# 749WCEL
# 750WCEL
# 751WCEL
# 752MRBTS
# 753HW
# 754WCEL
# 755WCEL
# 756WCEL
# 757WCEL
# 758WCEL
# 759WCEL
# 760WCEL
# 761WCEL
# 762WCEL
# 763MRBTS
# 764HW
# 765WCEL
# 766WCEL
# 767WCEL
# 768WCEL
# 769WCEL
# 770WCEL
# 771WCEL
# 772WCEL
# 773WCEL
# 774MRBTS
# 775HW
# 776WCEL
# 777WCEL
# 778WCEL
# 779WCEL
# 780WCEL
# 781WCEL
# 782WCEL
# 783WCEL
# 784WCEL
# 785MRBTS
# 786HW
# 787WCEL
# 788WCEL
# 789WCEL
# 790WCEL
# 791WCEL
# 792WCEL
# 793WCEL
# 794WCEL
# 795WCEL
# 796MRBTS
# 797HW
# 798WCEL
# 799WCEL
# 800WCEL
# 801WCEL
# 802WCEL
# 803WCEL
# 804WCEL
# 805WCEL
# 806WCEL
# 807MRBTS
# 808HW
# 809WCEL
# 810WCEL
# 811WCEL
# 812WCEL
# 813WCEL
# 814WCEL
# 815WCEL
# 816WCEL
# 817WCEL
# 818MRBTS
# 819HW
# 820WCEL
# 821WCEL
# 822WCEL
# 823WCEL
# 824WCEL
# 825WCEL
# 826WCEL
# 827WCEL
# 828WCEL
# 829MRBTS
# 830HW
# 831WCEL
# 832WCEL
# 833WCEL
# 834WCEL
# 835WCEL
# 836WCEL
# 837WCEL
# 838WCEL
# 839WCEL
# 840MRBTS
# 841HW
# 842WCEL
# 843WCEL
# 844WCEL
# 845WCEL
# 846WCEL
# 847WCEL
# 848MRBTS
# 849HW
# 850WCEL
# 851WCEL
# 852WCEL
# 853WCEL
# 854WCEL
# 855WCEL
# 856WCEL
# 857WCEL
# 858WCEL
# 859MRBTS
# 860HW
# 861WCEL
# 862WCEL
# 863WCEL
# 864WCEL
# 865WCEL
# 866WCEL
# 867WCEL
# 868WCEL
# 869WCEL
# 870MRBTS
# 871HW
# 872WCEL
# 873WCEL
# 874WCEL
# 875WCEL
# 876WCEL
# 877WCEL
# 878WCEL
# 879WCEL
# 880WCEL
# 881MRBTS
# 882HW
# 883WCEL
# 884WCEL
# 885WCEL
# 886WCEL
# 887WCEL
# 888WCEL
# 889WCEL
# 890WCEL
# 891WCEL
# 892MRBTS
# 893WCEL
# 894WCEL
# 895WCEL
# 896WCEL
# 897WCEL
# 898WCEL
# 899WCEL
# 900WCEL
# 901WCEL
# 902MRBTS
# 903WCEL
# 904WCEL
# 905WCEL
# 906WCEL
# 907WCEL
# 908WCEL
# 909WCEL
# 910WCEL
# 911WCEL
# 912MRBTS
# 913WCEL
# 914WCEL
# 915WCEL
# 916WCEL
# 917WCEL
# 918WCEL
# 919WCEL
# 920WCEL
# 921WCEL
# 922MRBTS
# 923HW
# 924WCEL
# 925WCEL
# 926WCEL
# 927WCEL
# 928WCEL
# 929WCEL
# 930WCEL
# 931WCEL
# 932WCEL
# 933MRBTS
# 934HW
# 935WCEL
# 936WCEL
# 937WCEL
# 938WCEL
# 939WCEL
# 940WCEL
# 941WCEL
# 942WCEL
# 943WCEL
# 944RMOD
# 945SMOD
# 946MODULE
# 947MODULE
# 948MODULE
# 949RMOD
# 950SMOD
# 951MODULE
# 952MODULE
# 953MODULE
# 954RMOD
# 955SMOD
# 956SMOD
# 957MODULE
# 958MODULE
# 959RMOD
# 960RMOD
# 961SMOD
# 962MODULE
# 963MODULE
# 964MODULE
# 965RMOD
# 966SMOD
# 967SMOD
# 968MODULE
# 969MODULE
# 970MODULE
# 971MODULE
# 972RMOD
# 973SMOD
# 974MODULE
# 975MODULE
# 976RMOD
# 977SMOD
# 978MODULE
# 979MODULE
# 980MODULE
# 981RMOD
# 982SMOD
# 983MODULE
# 984MODULE
# 985MODULE
# 986RMOD
# 987RMOD
# 988SMOD
# 989MODULE
# 990MODULE
# 991MODULE
# 992RMOD
# 993SMOD
# 994MODULE
# 995MODULE
# 996MODULE
# 997RMOD
# 998RMOD
# 999SMOD
# 1000MODULE
# 1001MODULE
# 1002MODULE
# 1003MODULE
# 1004RMOD
# 1005RMOD
# 1006RMOD
# 1007SMOD
# 1008MODULE
# 1009MODULE
# 1010MODULE
# 1011MODULE
# 1012MODULE
# 1013RMOD
# 1014RMOD
# 1015SMOD
# 1016MODULE
# 1017MODULE
# 1018MODULE
# 1019MODULE
# 1020MODULE
# 1021RMOD
# 1022SMOD
# 1023MODULE
# 1024MODULE
# 1025RMOD
# 1026SMOD
# 1027MODULE
# 1028MODULE
# 1029MODULE
# 1030RMOD
# 1031RMOD
# 1032SMOD
# 1033MODULE
# 1034MODULE
# 1035MODULE
# 1036RMOD
# 1037SMOD
# 1038MODULE
# 1039MODULE
# 1040MODULE
# 1041RMOD
# 1042SMOD
# 1043MODULE
# 1044MODULE
# 1045MODULE
# 1046RMOD
# 1047SMOD
# 1048MODULE
# 1049MODULE
# 1050MODULE
# 1051RMOD
# 1052RMOD
# 1053SMOD
# 1054MODULE
# 1055MODULE
# 1056RMOD
# 1057SMOD
# 1058MODULE
# 1059MODULE
# 1060RMOD
# 1061SMOD
# 1062MODULE
# 1063MODULE
# 1064RMOD
# 1065SMOD
# 1066MODULE
# 1067MODULE
# 1068MODULE
# 1069RMOD
# 1070SMOD
# 1071MODULE
# 1072MODULE
# 1073MODULE
# 1074RMOD
# 1075SMOD
# 1076MODULE
# 1077MODULE
# 1078RMOD
# 1079SMOD
# 1080MODULE
# 1081MODULE
# 1082MODULE
# 1083RMOD
# 1084SMOD
# 1085MODULE
# 1086MODULE
# 1087MODULE
# 1088RMOD
# 1089RMOD
# 1090SMOD
# 1091MODULE
# 1092MODULE
# 1093MODULE
# 1094MODULE
# 1095MODULE
# 1096RMOD
# 1097RMOD
# 1098SMOD
# 1099MODULE
# 1100MODULE
# 1101MODULE
# 1450WCEL
# 1451WCEL
# 1452WCEL
# 1453MRBTS
# 1454HW
# 1455WCEL
# 1456WCEL
# 1457WCEL
# 1458WCEL
# 1459WCEL
# 1460WCEL
# 1461WCEL
# 1462WCEL
# 1463WCEL
# 1464MRBTS
# 1465HW
# 1466WCEL
# 1467WCEL
# 1468WCEL
# 1469WCEL
# 1470WCEL
# 1471WCEL
# 1472WCEL
# 1473WCEL
# 1474WCEL
# 1475MRBTS
# 1476HW
# 1477WCEL
# 1478WCEL
# 1479WCEL
# 1480WCEL
# 1481WCEL
# 1482WCEL
# 1483WCEL
# 1484WCEL
# 1485WCEL
# 1486MRBTS
# 1487HW
# 1488WCEL
# 1489WCEL
# 1490WCEL
# 1491WCEL
# 1492WCEL
# 1493WCEL
# 1494WCEL
# 1495WCEL
# 1496WCEL
# 1497MRBTS
# 1498HW
# 1499WCEL
# 1500WCEL
# 1501WCEL
# 1502WCEL
# 1503WCEL
# 1504WCEL
# 1505WCEL
# 1506WCEL
# 1507WCEL
# 1508WCEL
# 1509WCEL
# 1510WCEL
# 1511MRBTS
# 1512HW
# 1513WCEL
# 1514WCEL
# 1515WCEL
# 1516WCEL
# 1517WCEL
# 1518WCEL
# 1519WCEL
# 1520WCEL
# 1521WCEL
# 1522MRBTS
# 1523HW
# 1524WCEL
# 1525WCEL
# 1526WCEL
# 1527WCEL
# 1528WCEL
# 1529WCEL
# 1530WCEL
# 1531WCEL
# 1532WCEL
# 1533MRBTS
# 1534HW
# 1535WCEL
# 1536WCEL
# 1537WCEL
# 1538MRBTS
# 1539HW
# 1540WCEL
# 1541WCEL
# 1542WCEL
# 1543WCEL
# 1544WCEL
# 1545WCEL
# 1546WCEL
# 1547WCEL
# 1548WCEL
# 1549MRBTS
# 1550HW
# 1551WCEL
# 1552WCEL
# 1553WCEL
# 1554WCEL
# 1555WCEL
# 1556WCEL
# 1557WCEL
# 1558WCEL
# 1559WCEL
# 1560MRBTS
# 1561HW
# 1562WCEL
# 1563WCEL
# 1564WCEL
# 1565WCEL
# 1566WCEL
# 1567WCEL
# 1568WCEL
# 1569WCEL
# 1570WCEL
# 1571MRBTS
# 1572HW
# 1573WCEL
# 1574WCEL
# 1575WCEL
# 1576WCEL
# 1577WCEL
# 1578WCEL
# 1579WCEL
# 1580WCEL
# 1581WCEL
# 1582MRBTS
# 1583HW
# 1584WCEL
# 1585WCEL
# 1586WCEL
# 1587WCEL
# 1588WCEL
# 1589WCEL
# 1590WCEL
# 1591WCEL
# 1592WCEL
# 1593MRBTS
# 1594HW
# 1595WCEL
# 1596WCEL
# 1597WCEL
# 1598WCEL
# 1599WCEL
# 1600WCEL
# 1601WCEL
# 1602WCEL
# 1603WCEL
# 1604WCEL
# 1605WCEL
# 1606WCEL
# 1607MRBTS
# 1608HW
# 1609WCEL
# 1610WCEL
# 1611WCEL
# 1612WCEL
# 1613WCEL
# 1614WCEL
# 1615WCEL
# 1616WCEL
# 1617WCEL
# 1618MRBTS
# 1619HW
# 1620WCEL
# 1621WCEL
# 1622WCEL
# 1623MRBTS
# 1624HW
# 1625WCEL
# 1976WCEL
# 1977WCEL
# 1978WCEL
# 1979WCEL
# 1980MRBTS
# 1981HW
# 1982WCEL
# 1983WCEL
# 1984WCEL
# 1985WCEL
# 1986WCEL
# 1987WCEL
# 1988WCEL
# 1989WCEL
# 1990WCEL
# 1991MRBTS
# 1992HW
# 1993WCEL
# 1994WCEL
# 1995WCEL
# 1996WCEL
# 1997WCEL
# 1998WCEL
# 1999WCEL
# 2000WCEL
# 2001WCEL
# 2002MRBTS
# 2003HW
# 2004WCEL
# 2005WCEL
# 2006WCEL
# 2007WCEL
# 2008WCEL
# 2009WCEL
# 2010WCEL
# 2011WCEL
# 2012WCEL
# 2013MRBTS
# 2014HW
# 2015WCEL
# 2016WCEL
# 2017WCEL
# 2018WCEL
# 2019WCEL
# 2020WCEL
# 2021WCEL
# 2022WCEL
# 2023WCEL
# 2024MRBTS
# 2025HW
# 2026WCEL
# 2027WCEL
# 2028WCEL
# 2029WCEL
# 2030WCEL
# 2031WCEL
# 2032WCEL
# 2033WCEL
# 2034WCEL
# 2035MRBTS
# 2036HW
# 2037WCEL
# 2038WCEL
# 2039WCEL
# 2040WCEL
# 2041WCEL
# 2042WCEL
# 2043WCEL
# 2044WCEL
# 2045WCEL
# 2046MRBTS
# 2047HW
# 2048WCEL
# 2049WCEL
# 2050WCEL
# 2051WCEL
# 2052WCEL
# 2053WCEL
# 2054WCEL
# 2055WCEL
# 2056WCEL
# 2057MRBTS
# 2058HW
# 2059WCEL
# 2060WCEL
# 2061WCEL
# 2062MRBTS
# 2063HW
# 2064WCEL
# 2065WCEL
# 2066WCEL
# 2067WCEL
# 2068WCEL
# 2069WCEL
# 2070WCEL
# 2071WCEL
# 2072WCEL
# 2073MRBTS
# 2074HW
# 2075WCEL
# 2076WCEL
# 2077WCEL
# 2078MRBTS
# 2079HW
# 2080WCEL
# 2081WCEL
# 2082WCEL
# 2083MRBTS
# 2084HW
# 2085WCEL
# 2086WCEL
# 2087WCEL
# 2088WCEL
# 2089WCEL
# 2090WCEL
# 2091WCEL
# 2092WCEL
# 2093WCEL
# 2094MRBTS
# 2095HW
# 2096WCEL
# 2097WCEL
# 2098WCEL
# 2099WCEL
# 2100WCEL
# 2101WCEL
# 2102WCEL
# 2103WCEL
# 2104WCEL
# 2105MRBTS
# 2106HW
# 2107WCEL
# 2108WCEL
# 2109WCEL
# 2110WCEL
# 2111WCEL
# 2112WCEL
# 2113WCEL
# 2114WCEL
# 2115WCEL
# 2116RMOD
# 2117SMOD
# 2118MODULE
# 2119MODULE
# 2120MODULE
# 2121RMOD
# 2122RMOD
# 2123SMOD
# 2124MODULE
# 2125MODULE
# 2126MODULE
# 2127MODULE
# 2128RMOD
# 2129RMOD
# 2130SMOD
# 2131MODULE
# 2132MODULE
# 2133MODULE
# 2134MODULE
# 2135RMOD
# 2136SMOD
# 2137MODULE
# 2138MODULE
# 2139MODULE
# 2140RMOD
# 2141SMOD
# 2142MODULE
# 2143MODULE
# 2144MODULE
# 2145RMOD
# 2146SMOD
# 2147MODULE
# 2148MODULE
# 2149MODULE
# 2150RMOD
# 2151RMOD
# 2152RMOD
# 2153SMOD
# 2154MODULE
# 2155MODULE
# 2156MODULE
# 2157MODULE
# 2158MODULE
# 2159RMOD
# 2160SMOD
# 2161MODULE
# 2162MODULE
# 2163MODULE
# 2164RMOD
# 2165SMOD
# 2166MODULE
# 2167MODULE
# 2168RMOD
# 2169SMOD
# 2170MODULE
# 2171MODULE
# 2172MODULE
# 2173RMOD
# 2174SMOD
# 2175MODULE
# 2176MODULE
# 2177MODULE
# 2178RMOD
# 2179SMOD
# 2180MODULE
# 2181MODULE
# 2182MODULE
# 2183RMOD
# 2184RMOD
# 2185SMOD
# 2186SMOD
# 2187MODULE
# 2188MODULE
# 2189MODULE
# 2190MODULE
# 2191RMOD
# 2192SMOD
# 2193MODULE
# 2194MODULE
# 2195MODULE
# 2196RMOD
# 2197SMOD
# 2198MODULE
# 2199MODULE
# 2200MODULE
# 2201RMOD
# 2202SMOD
# 2203MODULE
# 2204MODULE
# 2205MODULE
# 2206RMOD
# 2207SMOD
# 2208MODULE
# 2209MODULE
# 2210RMOD
# 2211SMOD
# 2212MODULE
# 2213MODULE
# 2214MODULE
# 2215RMOD
# 2216SMOD
# 2217MODULE
# 2218MODULE
# 2219RMOD
# 2220RMOD
# 2221SMOD
# 2222MODULE
# 2223MODULE
# 2224MODULE
# 2225MODULE
# 2226RMOD
# 2227SMOD
# 2228MODULE
# 2229MODULE
# 2230RMOD
# 2231SMOD
# 2232MODULE
# 2233MODULE
# 2234MODULE
# 2235RMOD
# 2236RMOD
# 2237RMOD
# 2238SMOD
# 2239MODULE
# 2240MODULE
# 2241MODULE
# 2242MODULE
# 2243RMOD
# 2244SMOD
# 2245MODULE
# 2246MODULE
# 2247MODULE
# 2248RMOD
# 2249RMOD
# 2250RMOD
# 2251SMOD
# 2252MODULE
# 2253MODULE
# 2254MODULE
# 2255MODULE
# 2256MODULE
# 2257RMOD
# 2258SMOD
# 2259MODULE
# 2260MODULE
# 2261MODULE
# 2262RMOD
# 2263SMOD
# 2264MODULE
# 2265MODULE
# 2266MODULE
# 2267RMOD
# 2268SMOD
# 2269MODULE
# 2270MODULE
# 2271MODULE
# 2272RMOD
# 2273RMOD
# 2274RMOD
# 2275SMOD
# 2276MODULE
# 2277MODULE
# 2278MODULE
# 2279MODULE
# 2280MODULE
# 2281RMOD
# 2282SMOD
# 2283MODULE
# 2284MODULE
# 2285RMOD
# 2286RMOD
# 2287RMOD
# 2288SMOD
# 2289MODULE
# 2290MODULE
# 2291MODULE
# 2292MODULE
# 2293RMOD
# 2294RMOD
# 2295SMOD
# 2296SMOD
# 2297MODULE
# 2298MODULE
# 2299MODULE
# 2300MODULE
# 2301MODULE
# 2302RMOD
# 2303RMOD
# 2304SMOD
# 2305MODULE
# 2306MODULE
# 2307RMOD
# 2308SMOD
# 2309RMOD
# 2310SMOD
# 2311MODULE
# 2312MODULE
# 2313MODULE
# 2314RMOD
# 2315SMOD
# 2316MODULE
# 2317MODULE
# 2318MODULE
# 2319RMOD
# 2320RMOD
# 2321RMOD
# 2322SMOD
# 2323MODULE
# 2324MODULE
# 2325MODULE
# 2326MODULE
# 2327MODULE
# 2328RMOD
# 2329SMOD
# 2330MODULE
# 2331MODULE
# 2332MODULE
# 2333RMOD
# 2334RMOD
# 2335SMOD
# 2336SMOD
# 2337MODULE
# 2338MODULE
# 2339MODULE
# 2340MODULE
# 2341RMOD
# 2342RMOD
# 2343SMOD
# 2344MODULE
# 2345MODULE
# 2346MODULE
# 2347MODULE
# 2348RMOD
# 2349RMOD
# 2350SMOD
# 2351SMOD
# 2352MODULE
# 2353MODULE
# 2354MODULE
# 2355MODULE
# 2356RMOD
# 2357RMOD
# 2358RMOD
# 2359SMOD
# 2360MODULE
# 2361MODULE
# 2362MODULE
# 2363MODULE
# 2364RMOD
# 2365RMOD
# 2366SMOD
# 2367SMOD
# 2368MODULE
# 2369MODULE
# 2370MODULE
# 2371MODULE
# 2372MODULE
# 2373RMOD
# 2374SMOD
# 2375MODULE
# 2376MODULE
# 2377MODULE
# 2378RMOD
# 2379SMOD
# 2380MODULE
# 2381MODULE
# 2382MODULE
# 2383RMOD
# 2384RMOD
# 2385SMOD
# 2386MODULE
# 2387MODULE
# 2388MODULE
# 2389MODULE
# 2390RMOD
# 2391SMOD
# 2392MODULE
# 2393MODULE
# 2394MODULE
# 2395RMOD
# 2396RMOD
# 2397SMOD
# 2398MODULE
# 2399MODULE
# 2400MODULE
# 2401MODULE
# 2402MODULE
# 2403RMOD
# 2404SMOD
# 2405MODULE
# 2406MODULE
# 2407RMOD
# 2408SMOD
# 2409MODULE
# 2410MODULE
# 2411MODULE
# 2412RMOD
# 2413SMOD
# 2414SMOD
# 2415MODULE
# 2416MODULE
# 2417RMOD
# 2418SMOD
# 2419SMOD
# 2420MODULE
# 2421MODULE
# 2422RMOD
# 2423SMOD
# 2424MODULE
# 2425MODULE
# 2426MODULE
# 2427RMOD
# 2428SMOD
# 2429MODULE
# 2430MODULE
# 2431MODULE
# 2432RMOD
# 2433SMOD
# 2434MODULE
# 2435MODULE
# 2436MODULE
# 2437WBTS
# 2438WBTS
# 2439WBTS
# 2440WBTS
# 2441WBTS
# 2442WBTS
# 2443WBTS
# 2444WBTS
# 2445WBTS
# 2446WBTS
# 2447WBTS
# 2448WBTS
# 2449WBTS
# 2450WBTS
# 2451WBTS
# 2452WBTS
# 2453WBTS
# 2454WBTS
# 2455WBTS
# 2456WBTS
# 2457WBTS
# 2458WBTS
# 2459WBTS
# 2460WBTS
# 2461WBTS
# 2462WBTS
# 2463WBTS
# 2464WBTS
# 2465WBTS
# 2466WBTS
# 2467WBTS
# 2468WBTS
# 2469WBTS
# 2470WBTS
# 2471WBTS
# 2472WBTS
# 2473WBTS
# 2474WBTS
# 2475WBTS
# 2476WBTS
# 2477WBTS
# 2478WBTS
# 2479WBTS
# 2480WBTS
# 2481WBTS
# 2482WBTS
# 2483WBTS
# 2484WBTS
# 2485WBTS
# 2486WBTS
# 2487WBTS
# 2488WBTS
# 2489WBTS
# 2490WBTS
# 2491WBTS
# 2492WBTS
# 2493WBTS
# 2494WBTS
# 2495WBTS
# 2496WBTS
# 2497WBTS
# 2498WBTS
# 2499WBTS
# 2500WBTS
# 2501WBTS
# 2502WBTS
# 2503WBTS
# 2504WBTS
# 2505WBTS
# 2506WBTS
# 2507WBTS
# 2508WBTS
# 2509WBTS
# 2510WBTS
# 2511WBTS
# 2512WBTS
# 2513WBTS
# 2514WBTS
# 2515WBTS
# 2516WBTS
# 2517WBTS
# 2518WBTS
# 2519WBTS
# 2520WBTS
# 2521WBTS
# 2522WBTS
# 2523WBTS
# 2524WBTS
# 2525WBTS
# 2526WBTS
# 2527WBTS
# 2528WBTS
# 2529WBTS
# 2530WBTS
# 2531WBTS
# 2532WBTS
# 2533WBTS
# 2534WBTS
# 2535WBTS
# 2536WBTS
# 2537WBTS
# 2538WBTS
# 2539WBTS
# 2540WBTS
# 2541WBTS
# 2542WBTS
# 2543WBTS
# 2544WBTS
# 2545WBTS
# 2546WBTS
# 2547WBTS
# 2548WBTS
# 2549WBTS
# 2550WBTS
# 2551WBTS
# 2552WBTS
# 2553WBTS
# 2554WBTS
# 2555WBTS
# 2556WBTS
# 2557MRBTS
# 2558HW
# 2559WCEL
# 2560WCEL
# 2561WCEL
# 2562WCEL
# 2563WCEL
# 2564WCEL
# 2565WCEL
# 2566WCEL
# 2567WCEL
# 2568MRBTS
# 2569WCEL
# 2570WCEL
# 2571WCEL
# 2572WCEL
# 2573WCEL
# 2574WCEL
# 2575WCEL
# 2576WCEL
# 2577WCEL
# 2578MRBTS
# 2579HW
# 2580WCEL
# 2581WCEL
# 2582WCEL
# 2583WCEL
# 2584WCEL
# 2585WCEL
# 2586WCEL
# 2587WCEL
# 2588WCEL
# 2589MRBTS
# 2590HW
# 2591WCEL
# 2592WCEL
# 2593WCEL
# 2594WCEL
# 2595WCEL
# 2596WCEL
# 2597WCEL
# 2598WCEL
# 2599WCEL
# 2600MRBTS
# 2601HW
# 2602WCEL
# 2603WCEL
# 2604WCEL
# 2605WCEL
# 2606WCEL
# 2607WCEL
# 2608WCEL
# 2609WCEL
# 2610WCEL
# 2611MRBTS
# 2612HW
# 2613WCEL
# 2614WCEL
# 2615WCEL
# 2616MRBTS
# 2617HW
# 2618WCEL
# 2619WCEL
# 2620WCEL
# 2621WCEL
# 2622WCEL
# 2623WCEL
# 2624WCEL
# 2625WCEL
# 2626WCEL
# 2627MRBTS
# 2628HW
# 2629WCEL
# 2630WCEL
# 2631WCEL
# 2632MRBTS
# 2633HW
# 2634WCEL
# 2635WCEL
# 2636WCEL
# 2637MRBTS
# 2638HW
# 2639WCEL
# 2640WCEL
# 2641WCEL
# 2642WCEL
# 2643WCEL
# 2644WCEL
# 2645WCEL
# 2646WCEL
# 2647WCEL
# 2648MRBTS
# 2649WCEL
# 2650WCEL
# 2651WCEL
# 2652WCEL
# 2653WCEL
# 2654WCEL
# 2655WCEL
# 2656WCEL
# 2657WCEL
# 2658MRBTS
# 2659HW
# 2660WCEL
# 2661WCEL
# 2662WCEL
# 2663WCEL
# 2664WCEL
# 2665WCEL
# 2666MRBTS
# 2667HW
# 2668WCEL
# 2669WCEL
# 2670WCEL
# 2671WCEL
# 2672WCEL
# 2673WCEL
# 2674WCEL
# 2675WCEL
# 2676WCEL
# 2677MRBTS
# 2678HW
# 2679WCEL
# 2680WCEL
# 2681WCEL
# 2682MRBTS
# 2683HW
# 2684WCEL
# 2685WCEL
# 2686WCEL
# 2687WCEL
# 2688WCEL
# 2689WCEL
# 2690WCEL
# 2691WCEL
# 2692WCEL
# 2693MRBTS
# 2694HW
# 2695WCEL
# 2696WCEL
# 2697WCEL
# 2698MRBTS
# 2699HW
# 2700WCEL
# 2701WCEL
# 2702WCEL
# 2703WCEL
# 2704WCEL
# 2705WCEL
# 2706WCEL
# 2707WCEL
# 2708WCEL
# 2709MRBTS
# 2710HW
# 2711WCEL
# 2712WCEL
# 2713WCEL
# 2714WCEL
# 2715WCEL
# 2716WCEL
# 2717WCEL
# 2718WCEL
# 2719WCEL
# 2720WCEL
# 2721WCEL
# 2722WCEL
# 2723WCEL
# 2724WCEL
# 2725WCEL
# 2726WCEL
# 2727WCEL
# 2728WCEL
# 2729WCEL
# 2730WCEL
# 2731WCEL
# 2732WCEL
# 2733WCEL
# 2734WCEL
# 2735WCEL
# 2736WCEL
# 2737WCEL
# 2738WCEL
# 2739WCEL
# 2740WCEL
# 2741WCEL
# 2742WCEL
# 2743WCEL
# 2744MRBTS
# 2745HW
# 2746WCEL
# 2747WCEL
# 2748WCEL
# 2749MRBTS
# 2750HW
# 2751WCEL
# 2752WCEL
# 2753WCEL
# 2754MRBTS
# 2755HW
# 2756WCEL
# 2757WCEL
# 2758WCEL
# 2759WCEL
# 2760WCEL
# 2761WCEL
# 2762WCEL
# 2763WCEL
# 2764WCEL
# 2765WCEL
# 2766WCEL
# 2767WCEL
# 2768MRBTS
# 2769HW
# 2770WCEL
# 2771WCEL
# 2772WCEL
# 2773WCEL
# 2774WCEL
# 2775WCEL
# 2776WCEL
# 2777WCEL
# 2778WCEL
# 2779MRBTS
# 2780HW
# 2781WCEL
# 2782WCEL
# 2783WCEL
# 2784WCEL
# 2785WCEL
# 2786WCEL
# 2787WCEL
# 2788WCEL
# 2789WCEL
# 2790MRBTS
# 2791HW
# 2792WCEL
# 2793WCEL
# 2794WCEL
# 2795MRBTS
# 2796HW
# 2797WCEL
# 2798WCEL
# 2799WCEL
# 2800WCEL
# 2801WCEL
# 2802WCEL
# 2803WCEL
# 2804WCEL
# 2805WCEL
# 2806MRBTS
# 2807HW
# 2808WCEL
# 2809WCEL
# 2810WCEL
# 2811WCEL
# 2812WCEL
# 2813WCEL
# 2814WCEL
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-46431fd921cd> in <module>
# ----> 1 xml_to_xlsx('SRAT Hardware dump_1.xml', 'class', 'SRAT')
#
# <ipython-input-9-ee953a7ab4a7> in xml_to_xlsx(input_file, sheet_attrib, output_file)
#       7     root = tree.getroot()
#       8
# ----> 9     dfs = data_xml(root, sheet_attrib)
#      10
#      11     # Opens the output file for writing
#
# <ipython-input-8-8f96d31c47af> in data_xml(root, sheet_attrib)
#      18         if i>0:
#      19             currNode = root[0][i]
# ---> 20             print(str(i)+str(currNode.attrib[sheet_attrib]))
#      21 #             print(currNode.attrib[sheet_attrib][0])
#      22             try:
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
